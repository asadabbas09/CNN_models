# %%
from keras.models import load_model

# returns a compiled model
# identical to the previous one
model = load_model('Model_save_2003.hdf5')
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv_1 (Conv2D)              (None, 64, 48, 48)        640
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 48, 48)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 48, 48)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 48, 48)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 64, 48, 48)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 48, 48)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 24, 24)        0
# ...
